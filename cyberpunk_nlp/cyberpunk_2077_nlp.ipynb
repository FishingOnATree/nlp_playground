# %%
##
## Follow the guide made available on https://int8.io/are-you-ok-cyberpunk-transformers-diagnosis/#Some_technical_details_8211_data_source_preprocessing_embedding
##

# %%
import nltk
nltk.download('punkt')

# %%
## Download cyberpunk reviews
from fetcher import SteamReviewFetcher


fetcher = SteamReviewFetcher(1091500, "./data")
fetcher.collect_reviews()
# Out:
# INFO:hitting https://store.steampowered.com/appreviews/1091500?json=1&&language=english&filter=updated&review_type=all&purchase_type=all&cursor=*&num_per_page=100
# INFO:data for cursor=* already exists - moving to the next cursor
# INFO:data for cursor=AoJ4jIaMwfYCc97nuwI%3D already exists - moving to the next cursor
# INFO:data for cursor=AoJ4zNOHwfYCd6bnuwI%3D already exists - moving to the next cursor
# INFO:data for cursor=AoJwuv2CwfYCfujmuwI%3D already exists - moving to the next cursor
# INFO:data for cursor=AoJw8qP%2BwPYCcPbvuAI%3D already exists - moving to the next cursor
# INFO:data for cursor=AoJ4qd/5wPYCfZrGuAI%3D already exists - moving to the next cursor
# INFO:data for cursor=AoJ4/qX1wPYCdrTluwI%3D already exists - moving to the next cursor
# INFO:data for cursor=AoJ48IzxwPYCcbO5ugI%3D already exists - moving to the next cursor
# INFO:data for cursor=AoJw34zswPYCfqjkuwI%3D already exists - moving to the next cursor
# ...

# %%
sentences.head()
# Out:
#   recommendation_id    author_steam_id  author_num_games_owned  \
# 0          82090611  76561198049056464                     240
# 1          82090611  76561198049056464                     240
# 2          82090611  76561198049056464                     240
# 3          82090611  76561198049056464                     240
# 4          82788514  76561198045088523                      44
#
#    author_num_reviews  author_playtime_forever  \
# 0                  15                     1492
# 1                  15                     1492
# 2                  15                     1492
# 3                  15                     1492
# 4                   1                     1934
#
#    author_playtime_last_two_weeks  voted_up  \
# 0                            1492     False
# 1                            1492     False
# 2                            1492     False
# 3                            1492     False
# 4                            1934      True
#
# ...

# %%
len(sentences)
# Out:
# 472302

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('roberta-large-nli-stsb-mean-tokens')
sentence_embeddings = model.encode(sentences['sentence'])
# Out:
# INFO:Load pretrained SentenceTransformer: roberta-large-nli-stsb-mean-tokens
# INFO:Did not find folder roberta-large-nli-stsb-mean-tokens
# INFO:Try to download model from server: https://sbert.net/models/roberta-large-nli-stsb-mean-tokens.zip
# INFO:Load SentenceTransformer from folder: C:\Users\raysu/.cache\torch\sentence_transformers\sbert.net_models_roberta-large-nli-stsb-mean-tokens
# INFO:Use pytorch device: cuda
# ...
